# %%
import requests
from bs4 import BeautifulSoup

import pymarkovchain

from string import punctuation
punctuation += '«»—'

# %%
def get_last_page_number(domain, navigation_attrs = {'class' : 'page-numbers'}):
    response = requests.get(domain)
    html = response.text
    soup = BeautifulSoup(html, 'lxml')
    last_page = int( soup.find_all(attrs = navigation_attrs)[-2].get_text() )
    return last_page

# %%
def get_titles(domain, last_page_number, title_attrs = {'class' : 'entry-title'}):
    titles = []
    
    for page in range(last_page_number):
        response = requests.get('{}/page/{}/'.format(domain, page))
        html = response.text
        soup = BeautifulSoup(html, 'lxml')
        titles += [ title.get_text() for title in soup.find_all(attrs = title_attrs) ]
        
    return titles

# %%
start = 'http://searchstart.ru'
last_page = get_last_page_number(start)
titles = get_titles(start, last_page)

# %% [markdown]
# -------

# %%
with open('news_titles.txt', 'w') as f:
    f.write('\n'.join(titles))

# %%
with open('news_titles.txt') as f:
    titles = [line.strip() for line in f.readlines()]

# %% [markdown]
# -------

# %%
titles = '\n'.join([''.join([char for char in title if char not in punctuation]) for title in titles]).lower()

# %%
mc = pymarkovchain.MarkovChain()
mc.generateDatabase(titles)
# Out:
# WARNING:root:Database file corrupt or not found, using empty database

# %%
for _ in range(100): print(mc.generateString())
# Out:
# рылов бронзовый призер олимпиады
# глина паста воск клей и еще 5 необычных вещей которые делает твое тело во время домашних соревнований по метанию ножа
# бобровский ринне
# первые изображения
# чуркин с особым удовольствием ставит с пауэр на место
# источники узнали о прогнозе мвф с ценой на нефть
# турция готова впускать россиян по закону
# уникальная методика и чё
# угарные пранки над друзьями в школе библию вместо войны и мира
# вечерний ургант юрий вяземский екатерина гусева 697 выпуск от 18102016
# дорогам продлили нормогоды
# лукашенко раздеваться и работать
# пилот не пострадал
# официально стал президентом
# в сирии защищая гуманитарный конвой
# западные звезды говорят порусски
# жарим мраморные стейки на углях дома
# 10 лучших мультиков короткометражек от студии pixar
# сми узнали о выделении терминала для россиян
# персонажи крестного хода город екатеринбург
# this is хорошо мимо
# вицеспикер рады раскрыла детали передачи савченко
# доставь удовольствие природе гринпис высмеяла в пародии социальные видеоролики которые ничего не объясняй
# развод джоли и брэда питта останутся с матерью
# туристамодиночкам подсказали способы устроить лучший в жизни отпуск
# лев против пьяный дебош
# pharaoh гарри топор fuze и вахтанг 21062016
# мвф
# фанаты гарри поттера гермиона все еще жива
# суд отказался считать новых лидеров болгарии и молдавии пророссийскими
# чемпионат мира среди тренеров каким будет английский сезон
# 10 финальных сцен после титров из фильмов
# пробка
# вся правда о гмо
# горячий чай у полярного круга
# 15 сериалов для тех кому надоело жить постарому
# смену руководства рбк с давлением извне
# объявлена дата выхода новой части игры
# что россиян не смогут жить дольше
# в истории страны ракетуноситель
# футболисты краснодара стартовали на групповом этапе лиги европы
# 20 млн
# непростые жизненные уроки необходимо усвоить к 30 годам тюрьмы
# что делать
# организаторы ищут выигравшего в лотерею 17 млн рублей
# научные нубы
# подмосковный депутат сообщил о квартальном операционном убытке изза матч тв опубликовал список 14 допингеров олимпиады2008
# владимир путин для будущего нации вредно купаться в своем банке
# 7 ужасных случаев изза фруктов
# правительство одобрило создание объединенной региональной системы пво на кавказе
# власти бельгии сообщили об освобождении границы с сирией ракетные установки
# что любимый кофе говорит о вашей личности
# кремль прокомментировал присвоение мосту в петербурге открывают мемориальную доску легендарному репортеру матвею фролову
# мессенджеры
# в сборную россии могут заблокировать
# журналистов к минобороны
# главное за неделю повышение цен на нефть в 75 за баррель
# реальные имена любимых диснеевских героев ваши друзья такого еще не опубликована цитаты оттуда спекуляция
# члены банды gta сознались в многочисленных убийствах на дорогах смешные приколы
# один из крупнейших в мире морской секскруиз
# мария захарова рассказала о шариковой ручке по аналогии с роликами apple
# бомбезные факты про терминатора
# в экономике
# в британии бесследно исчезли сотни детейбеженцев
# вечерний ургант дима билан 710 выпуск от 20102016
# маккейн недоволен тем как ржд проводит оптимизацию расходов
# в которых наука ошибалась
# лучшее начало года за употребление допинга
# в воду
# мвд
# топ 5 лучших видео за июнь 2016
# промышленность создала миф о завтраке
# 10 интернет мемов спустя годы
# в сша признал россиянина селезнева виновным в получении взяток
# 10 важных фактов о земле про которые ты должен освоить
# гвардьола третий испанский барьер
# топ5 порноактрис
# как умер чемпион по биатлону в 2021 году пройдет референдум о прямых выборах губернатора
# вопросы на которые многие верят
# история motorola почему развалилась компания выпустившая первый пейджер и коммерческий сотовый телефон
# 10 исключительных методов противодействия списыванию на экзаменах
# госдума заставит платить блогеров налоги
# витсель отказался продлевать контракт с роскосмосом продлен не будет
# как накачать попу тренировка ягодиц для красивых девушек
# госдума уточнила понятие состояние опьянения
# депутаты госдумы отчитались о доходах президента
# президент мурси внесен в список боевиков 614 человек из них
# кто отвечает за преступления которые совершают алгоритмы
# министр образования пообещала вернуть астрономию в школьную программу
# студент из китая с пультом и изменяемой яркостью и цветовой температурой
# укроборонпрому поручили создать не уступающее российскому оружие
# правительство начало приватизацию алросы
# взрослого человека впервые вылечили от вич успешно прошла испытания на обезьянах
# русалки снятые на камеру
# с безлимитным интернетом
# кадыров посетил закрытую тренировку сборной россии на домашних роутерах через мобильные устройства
# жена шеремета рассказала о расставании с шоном пенном
# постановление об опасном вождении
# объединение тройки и подорожника перенесли на 2020 год
# интерфакс соообщил о третьем случае опасного сближения самолетов над японским морем

# %%
s = 'турция объявила'
index = titles.find(s)
titles[index : index+100]
# Out:
# 'турция объявила о безвизовом режиме для стран шенгенской зоны\nщедрые монголы на mercedes спровоциров'
